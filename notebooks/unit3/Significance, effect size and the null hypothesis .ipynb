# %% [markdown]
# ### The null hypothesis
#
# When we test for statistical significance, we often assume a "null" hypothesis. For our purposes, we can think of the "null" hypothesis as the distribution of the data, if the treatment has no effect. In this notebook we will test this out.

# %% [markdown]
# ### Test statistic
#
# To test the null hypothesis, we need to compute a test statistic $T$. A statistic is a function from data. A function is a mapping from a domain to a range, such that each element in the domain maps to exactly one element in the range. Any statistic from data can be a test statistic.

# %%
import pandas as pd
import altair as alt
import numpy as np

def T_stat(X, Y):
    '''
    Return T, the absolute value of the difference between the means of
    X and Y
    
    Formally, this is \vert \frac{\Sigma x_i}{N_x} \frac{\Sigma y_i}{N_y} \vert
    where N_x is the number of elements in group x. 
    '''
    pass

# %% [markdown]
# #### Assume the null
#
# In prior exercizes we have assumed there is a difference between the treatment and control groups. For this exercize we will assume that the null hypothesis is true. There is no difference between treatment and control.
#
# In the cell below, draw 10 points at random from a normal distribution with mean 0 and sd 1 for the "teatment" group. Then draw 10 more points for the "control" group. Then compute $T$ based on that data.
#
# In this case, we know that the null hypothesis is true and that there is no real difference between treatment and control. (In real life, we won't know if the treatment has a real effect of course; this example is to help us understand statistics).

# %%
def draw_points_compute_T(mu=0, sd=1, N=10):
    '''
    Draw 10 points from 'treatment' and 10 from 'control'
    Assume the null distribution is normal
    After drawing treatment and control, compute a T statistic and return T
    '''
    # complete me

T = draw_points_compute_T()

# %% [markdown]
# #### What is the p value?
#
# Is your result significant? Well, we know that the null is true. But we can still compute significance. Remember that significance is the probability of observing something $T$ or higher under the null. How can we get this probability? Well, in this case we are lucky and can just keep drawing from the distribution to find out using simulation! But in the future we will learn about how to handle cases when you can't just get infinite data (which is usually true in the real world).

# %%
def get_P(T, mu=0, sd=1, N=10, trials=1000):
    '''
    Compute a p-value for the statistic $T$ from a distribution with 
    mean mu, standard deviation sd where you draw N points for the 
    treatment and control.
    
    To compute the p-value, simulate 1000 draws from the null distribution
    What fraction of the draws do you observe a test statistic higher than
    T? 
    '''
    
    c = 0 
    
    for trial in range(trials):
        # complete me
    
    return c/trials

get_P(T)
# Out:
# 0.557

# %% [markdown]
# #### What is the relationship between T and the p-value?
#
# Run the experiment 1000 times, drawing random values of $T$ and observing their p-values. Make a scatter plot. What do you observe?

# %%
data = []
for i in range(1000):
    # pass
    
# make a plot
# Out:
# alt.Chart(...)
